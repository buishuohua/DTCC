# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
symbol = "JPM"
start_date = dt.datetime(2008, 1, 1)
end_date = dt.datetime(2009, 12, 31)
df = pd.read_csv("data/{}.csv".format(symbol), index_col="Date", parse_dates=True)
df.drop(["Close"], axis=1, inplace=True)
df = df.rename(columns={"Adj Close": "Close"})
df
# Out:
#              Open   High    Low    Volume  Close
# Date
# 2012-09-12  39.88  40.25  39.79  29882200  39.92
# 2012-09-11  38.80  39.63  38.73  22378900  39.60
# 2012-09-10  39.23  39.78  38.73  20853500  38.76
# 2012-09-07  39.04  39.53  39.00  28082400  39.30
# 2012-09-06  37.58  38.87  37.50  41346800  38.69
# ...           ...    ...    ...       ...    ...
# 2000-02-07  82.19  83.37  81.75   4684200  37.37
# 2000-02-04  82.50  83.31  81.56   5115100  37.17
# 2000-02-03  83.50  84.87  80.25   9200200  37.82
# 2000-02-02  83.00  84.19  81.37   7126200  37.45
# 2000-02-01  82.44  84.50  81.31   9651000  38.08
#
# [3175 rows x 5 columns]

# %%
def MACD(df: pd.DataFrame, short_window=12, long_window=26, signal_window=9)->pd.DataFrame:
    # Calculate the short / long term exponential moving average (short_window EMA)
    short_ema = df["Close"].ewm(span=short_window, adjust=False).mean()
    long_ema = df["Close"].ewm(span=long_window, adjust=False).mean()
    macd = short_ema - long_ema
    signal = macd.ewm(span=signal_window, adjust=False).mean()
    histogram = macd - signal
    buy_signal = (macd.shift(1) < signal.shift(1)) & (macd > signal)
    sell_signal = (macd.shift(1) > signal.shift(1)) & (macd < signal)
    df_macd = pd.DataFrame({'MACD': macd, 'Signal Line': signal, 'Histogram': histogram, 'Buy Signal': buy_signal, 'Sell Signal': sell_signal})

    return df_macd


MACD(df)
# Out:
#                 MACD  Signal Line  Histogram  Buy Signal  Sell Signal
# Date
# 2012-09-12  0.000000     0.000000   0.000000       False        False
# 2012-09-11 -0.025527    -0.005105  -0.020422       False        False
# 2012-09-10 -0.112245    -0.026533  -0.085711       False        False
# 2012-09-07 -0.135830    -0.048392  -0.087437       False        False
# 2012-09-06 -0.201421    -0.078998  -0.122423       False        False
# ...              ...          ...        ...         ...          ...
# 2000-02-07 -0.008501    -0.385539   0.377038       False        False
# 2000-02-04  0.005611    -0.307309   0.312920       False        False
# 2000-02-03  0.068455    -0.232156   0.300611       False        False
# 2000-02-02  0.087396    -0.168246   0.255642       False        False
# 2000-02-01  0.151496    -0.104297   0.255794       False        False
#
# [3175 rows x 5 columns]

# %%
def BollingerBands(df: pd.DataFrame, window=20, num_std=2) -> pd.DataFrame:
    rolling_mean = df["Close"].rolling(window=window).mean()
    rolling_std = df["Close"].rolling(window=window).std()
    upper_band = rolling_mean + (rolling_std * num_std)
    lower_band = rolling_mean - (rolling_std * num_std)
    bbp = (df["Close"] - lower_band) / (upper_band - lower_band)

    # Create a DataFrame that contains the original price, rolling mean, upper band, lower band, and signals
    df_bollinger = pd.DataFrame({
        'Rolling Mean': rolling_mean,
        'Upper Band': upper_band,
        'Lower Band': lower_band,
        'Signal': bbp
    })

    return df_bollinger

BollingerBands(df)
# Out:
#             Rolling Mean  Upper Band  Lower Band    Signal
# Date
# 2012-09-12           NaN         NaN         NaN       NaN
# 2012-09-11           NaN         NaN         NaN       NaN
# 2012-09-10           NaN         NaN         NaN       NaN
# 2012-09-07           NaN         NaN         NaN       NaN
# 2012-09-06           NaN         NaN         NaN       NaN
# ...                  ...         ...         ...       ...
# 2000-02-07        36.365   38.980472   33.749528  0.692126
# 2000-02-04        36.327   38.867751   33.786249  0.665896
# 2000-02-03        36.374   38.991443   33.756557  0.776224
# 2000-02-02        36.415   39.074675   33.755325  0.694573
# 2000-02-01        36.455   39.192379   33.717621  0.796817
#
# [3175 rows x 4 columns]

# %%
def RSI(df: pd.DataFrame, window=14)->pd.DataFrame:
    
    # Calculate daily returns
    daily_returns = df["Close"].diff()
    # Calculate up days and down days
    up_days = daily_returns.where(daily_returns > 0, 0)
    down_days = -daily_returns.where(daily_returns < 0, 0)
    # Calculate average gain and average loss
    avg_gain = up_days.rolling(window=window).mean()
    avg_loss = down_days.rolling(window=window).mean()
    # Calculate relative strength
    rs = avg_gain / (avg_loss + 1e-10)
    # Calculate RSI
    rsi = 100 - (100 / (1 + rs))
    
    
    rsi_df = pd.DataFrame({
        "Close_RSI": rsi
    })
    return rsi_df


RSI(df)
# Out:
#             Close_RSI
# Date
# 2012-09-12        NaN
# 2012-09-11        NaN
# 2012-09-10        NaN
# 2012-09-07        NaN
# 2012-09-06        NaN
# ...               ...
# 2000-02-07  58.931860
# 2000-02-04  63.241107
# 2000-02-03  65.266106
# 2000-02-02  60.861244
# 2000-02-01  63.430127
#
# [3175 rows x 1 columns]

# %%
# Function to compute volume-based features with lowercase column names
def compute_volume_features(df):
    df = df.copy()
    
    # 1. On-Balance Volume (OBV)
    df['OBV'] = (np.sign(df['Close'].diff()) * df['Volume']).fillna(0).cumsum()
    
    # 2. Volume Rate of Change (VROC)
    df['VROC_10'] = df['Volume'].pct_change(10)
    df['VROC_20'] = df['Volume'].pct_change(20)

    # 3. Accumulation/Distribution Index (ADI)
    df['ADI'] = ((df['Close'] - df['Low']) - (df['High'] - df['Close'])) / (df['High'] - df['Low']) * df['Volume']
    df['ADI_CUMSUM'] = df['ADI'].cumsum()

    # 4. Volume Weighted Average Price (VWAP)
    df['VWAP'] = (df['Volume'] * (df['High'] + df['Low'] + df['Close']) / 3).cumsum() / df['Volume'].cumsum()

    # 5. Moving Average of Volume (SMA of Volume)
    df['SMA_VOL_10'] = df['Volume'].rolling(window=10).mean()
    df['SMA_VOL_20'] = df['Volume'].rolling(window=20).mean()

    # 6. Exponential Moving Average of Volume (EMA of Volume)
    df['EMA_VOL_10'] = df['Volume'].ewm(span=10, adjust=False).mean()
    df['EMA_VOL_20'] = df['Volume'].ewm(span=20, adjust=False).mean()

    # 7. Volume Standard Deviation
    df['VOL_STD_10'] = df['Volume'].rolling(window=10).std()
    df['VOL_STD_20'] = df['Volume'].rolling(window=20).std()

    # 8. Volume Z-Score (Normalization)
    df['VOLUME_ZSCORE'] = (df['Volume'] - df['Volume'].rolling(window=20).mean()) / df['Volume'].rolling(window=20).std()

    # 9. Volume Trend Strength (Difference from Moving Average)
    df['VOLUME_TREND'] = df['Volume'] - df['SMA_VOL_10']

    # 10. Volume Surge Indicator (Ratio of Current Volume to 10-day Average)
    df['VOLUME_SURGE'] = df['Volume'] / df['SMA_VOL_10']

    return df


# Compute volume-based features with lowercase columns
compute_volume_features(df)
# Out:
#              Open   High    Low    Volume  Close           OBV   VROC_10  \
# Date
# 2012-09-12  39.88  40.25  39.79  29882200  39.92  0.000000e+00       NaN
# 2012-09-11  38.80  39.63  38.73  22378900  39.60 -2.237890e+07       NaN
# 2012-09-10  39.23  39.78  38.73  20853500  38.76 -4.323240e+07       NaN
# 2012-09-07  39.04  39.53  39.00  28082400  39.30 -1.515000e+07       NaN
# 2012-09-06  37.58  38.87  37.50  41346800  38.69 -5.649680e+07       NaN
# ...           ...    ...    ...       ...    ...           ...       ...
# 2000-02-07  82.19  83.37  81.75   4684200  37.37  1.326891e+09 -0.337323
# 2000-02-04  82.50  83.31  81.56   5115100  37.17  1.321776e+09 -0.370162
# 2000-02-03  83.50  84.87  80.25   9200200  37.82  1.330976e+09  0.609496
# 2000-02-02  83.00  84.19  81.37   7126200  37.45  1.323850e+09  0.475495
# 2000-02-01  82.44  84.50  81.31   9651000  38.08  1.333501e+09  0.076460
#
#              VROC_20           ADI    ADI_CUMSUM       VWAP  SMA_VOL_10  \
# Date
# 2012-09-12       NaN -1.299226e+07 -1.299226e+07  39.986667         NaN
# 2012-09-11       NaN  2.088697e+07  7.894712e+06  39.701191         NaN
# 2012-09-10       NaN -1.966187e+07 -1.176716e+07  39.526869         NaN
# 2012-09-07       NaN  3.708996e+06 -8.058163e+06  39.457437         NaN
# 2012-09-06       NaN  3.048195e+07  2.242378e+07  39.137177         NaN
# ...              ...           ...           ...        ...         ...
# 2000-02-07  0.025685 -2.613321e+08 -5.312998e+11  36.692546   6829170.0
# 2000-02-04 -0.101258 -2.646114e+08 -5.315644e+11  36.694587   6528550.0
# 2000-02-03  0.538135 -1.781892e+08 -5.317426e+11  36.698295   6876950.0
# 2000-02-02  0.988448 -2.290997e+08 -5.319717e+11  36.701169   7106600.0
# 2000-02-01  0.983232 -2.712264e+08 -5.322429e+11  36.705096   7175150.0
#
#             SMA_VOL_20    EMA_VOL_10    EMA_VOL_20    VOL_STD_10  \
# Date
# 2012-09-12         NaN  2.988220e+07  2.988220e+07           NaN
# 2012-09-11         NaN  2.851796e+07  2.916760e+07           NaN
# 2012-09-10         NaN  2.712442e+07  2.837578e+07           NaN
# 2012-09-07         NaN  2.729860e+07  2.834784e+07           NaN
# 2012-09-06         NaN  2.985282e+07  2.958584e+07           NaN
# ...                ...           ...           ...           ...
# 2000-02-07   6099910.0  6.549147e+06  6.512176e+06  1.705381e+06
# 2000-02-04   6071095.0  6.288411e+06  6.379121e+06  1.717221e+06
# 2000-02-03   6232035.0  6.817827e+06  6.647796e+06  1.879823e+06
# 2000-02-02   6409155.0  6.873895e+06  6.693358e+06  1.736763e+06
# 2000-02-01   6648390.0  7.378823e+06  6.975038e+06  1.829346e+06
#
#               VOL_STD_20  VOLUME_ZSCORE  VOLUME_TREND  VOLUME_SURGE
# Date
# 2012-09-12           NaN            NaN           NaN           NaN
# 2012-09-11           NaN            NaN           NaN           NaN
# 2012-09-10           NaN            NaN           NaN           NaN
# 2012-09-07           NaN            NaN           NaN           NaN
# 2012-09-06           NaN            NaN           NaN           NaN
# ...                  ...            ...           ...           ...
# 2000-02-07  1.557889e+06      -0.908736    -2144970.0      0.685911
# 2000-02-04  1.571116e+06      -0.608481    -1413450.0      0.783497
# 2000-02-03  1.719316e+06       1.726363     2323250.0      1.337831
# 2000-02-02  1.611209e+06       0.445035       19600.0      1.002758
# 2000-02-01  1.721511e+06       1.744172     2475850.0      1.345059
#
# [3175 rows x 20 columns]

# %%
combined_df = pd.concat([compute_volume_features(df), MACD(df), BollingerBands(df), RSI(df)], axis=1)
combined_df
# Out:
#              Open   High    Low    Volume  Close           OBV   VROC_10  \
# Date
# 2012-09-12  39.88  40.25  39.79  29882200  39.92  0.000000e+00       NaN
# 2012-09-11  38.80  39.63  38.73  22378900  39.60 -2.237890e+07       NaN
# 2012-09-10  39.23  39.78  38.73  20853500  38.76 -4.323240e+07       NaN
# 2012-09-07  39.04  39.53  39.00  28082400  39.30 -1.515000e+07       NaN
# 2012-09-06  37.58  38.87  37.50  41346800  38.69 -5.649680e+07       NaN
# ...           ...    ...    ...       ...    ...           ...       ...
# 2000-02-07  82.19  83.37  81.75   4684200  37.37  1.326891e+09 -0.337323
# 2000-02-04  82.50  83.31  81.56   5115100  37.17  1.321776e+09 -0.370162
# 2000-02-03  83.50  84.87  80.25   9200200  37.82  1.330976e+09  0.609496
# 2000-02-02  83.00  84.19  81.37   7126200  37.45  1.323850e+09  0.475495
# 2000-02-01  82.44  84.50  81.31   9651000  38.08  1.333501e+09  0.076460
#
#              VROC_20           ADI    ADI_CUMSUM  ...      MACD  Signal Line  \
# Date                                              ...
# 2012-09-12       NaN -1.299226e+07 -1.299226e+07  ...  0.000000     0.000000
# 2012-09-11       NaN  2.088697e+07  7.894712e+06  ... -0.025527    -0.005105
# 2012-09-10       NaN -1.966187e+07 -1.176716e+07  ... -0.112245    -0.026533
# 2012-09-07       NaN  3.708996e+06 -8.058163e+06  ... -0.135830    -0.048392
# 2012-09-06       NaN  3.048195e+07  2.242378e+07  ... -0.201421    -0.078998
# ...              ...           ...           ...  ...       ...          ...
# 2000-02-07  0.025685 -2.613321e+08 -5.312998e+11  ... -0.008501    -0.385539
# 2000-02-04 -0.101258 -2.646114e+08 -5.315644e+11  ...  0.005611    -0.307309
# 2000-02-03  0.538135 -1.781892e+08 -5.317426e+11  ...  0.068455    -0.232156
# 2000-02-02  0.988448 -2.290997e+08 -5.319717e+11  ...  0.087396    -0.168246
# 2000-02-01  0.983232 -2.712264e+08 -5.322429e+11  ...  0.151496    -0.104297
#
#             Histogram  Buy Signal  Sell Signal  Rolling Mean  Upper Band  \
# Date
# 2012-09-12   0.000000       False        False           NaN         NaN
# 2012-09-11  -0.020422       False        False           NaN         NaN
# 2012-09-10  -0.085711       False        False           NaN         NaN
# 2012-09-07  -0.087437       False        False           NaN         NaN
# 2012-09-06  -0.122423       False        False           NaN         NaN
# ...               ...         ...          ...           ...         ...
# 2000-02-07   0.377038       False        False        36.365   38.980472
# 2000-02-04   0.312920       False        False        36.327   38.867751
# 2000-02-03   0.300611       False        False        36.374   38.991443
# 2000-02-02   0.255642       False        False        36.415   39.074675
# 2000-02-01   0.255794       False        False        36.455   39.192379
#
#             Lower Band    Signal  Close_RSI
# Date
# 2012-09-12         NaN       NaN        NaN
# 2012-09-11         NaN       NaN        NaN
# 2012-09-10         NaN       NaN        NaN
# 2012-09-07         NaN       NaN        NaN
# 2012-09-06         NaN       NaN        NaN
# ...                ...       ...        ...
# 2000-02-07   33.749528  0.692126  58.931860
# 2000-02-04   33.786249  0.665896  63.241107
# 2000-02-03   33.756557  0.776224  65.266106
# 2000-02-02   33.755325  0.694573  60.861244
# 2000-02-01   33.717621  0.796817  63.430127
#
# [3175 rows x 30 columns]

# %%
combined_df.to_csv("featured_data/{}.csv".format(symbol))

# %% [markdown]
# ## Automation

# %%
import os
# Create the output folder if it does not exist
os.makedirs("featured_data", exist_ok=True)

# Process all CSV files in the "data" directory
data_folder = "data"

for file in os.listdir(data_folder):
    if file.endswith(".csv"):
        symbol = file.replace(".csv", "")
        file_path = os.path.join(data_folder, file)

        # Load data
        try:
            df = pd.read_csv(file_path, index_col="Date", parse_dates=True)
        except Exception as e:
            print(f"Error reading {file_path}: {str(e)}")
            continue

        # Process DataFrame
        if "Close" in df.columns:
            df.drop(["Close"], axis=1, inplace=True)
        df = df.rename(columns={"Adj Close": "Close"})

        # Apply feature engineering
        combined_df = pd.concat([compute_volume_features(df), MACD(df), BollingerBands(df), RSI(df)],axis=1)

        # Save to new CSV
        output_file = os.path.join("featured_data", f"{symbol}.csv")
        combined_df.to_csv(output_file)
        print(f"Processed and saved: {output_file}")
# Out:
# Processed and saved: featured_data/PHM.csv
# Processed and saved: featured_data/ML4T-309.csv
# Processed and saved: featured_data/FRX.csv
# Processed and saved: featured_data/GLD.csv
# Processed and saved: featured_data/JPM.csv
# Processed and saved: featured_data/ML4T-357.csv
# Processed and saved: featured_data/HIG.csv
# Processed and saved: featured_data/LEN.csv
# Processed and saved: featured_data/BSC.csv
# Processed and saved: featured_data/AVY.csv
# Processed and saved: featured_data/ML4T-239.csv
# /tmp/ipykernel_892722/2545850965.py:9: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['VROC_10'] = df['Volume'].pct_change(10)
# /tmp/ipykernel_892722/2545850965.py:10: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['VROC_20'] = df['Volume'].pct_change(20)
# Processed and saved: featured_data/ML4T-072.csv
# Processed and saved: featured_data/THC.csv
# Processed and saved: featured_data/ML4T-041.csv
# Processed and saved: featured_data/ML4T-027.csv
# Processed and saved: featured_data/ML4T-381.csv
# Processed and saved: featured_data/IVZ.csv
# Processed and saved: featured_data/ML4T-156.csv
# Processed and saved: featured_data/BJS.csv
# Processed and saved: featured_data/SINE_SLOW_NOISE.csv
# Processed and saved: featured_data/ML4T-051.csv
# Processed and saved: featured_data/SNV.csv
# Processed and saved: featured_data/CVH.csv
# Processed and saved: featured_data/ML4T-145.csv
# Processed and saved: featured_data/FAKE2.csv
# Processed and saved: featured_data/MMM.csv
# Processed and saved: featured_data/ML4T-105.csv
# Processed and saved: featured_data/ML4T-234.csv
# Processed and saved: featured_data/ML4T-286.csv
# Processed and saved: featured_data/ML4T-261.csv
# Processed and saved: featured_data/XRAY.csv
# Processed and saved: featured_data/ML4T-066.csv
# Processed and saved: featured_data/DFS.csv
# Processed and saved: featured_data/GLW.csv
# Processed and saved: featured_data/ITW.csv
# Processed and saved: featured_data/ML4T-042.csv
# Processed and saved: featured_data/LIFE.csv
# Processed and saved: featured_data/ABI.csv
# Processed and saved: featured_data/TWX.csv
# Processed and saved: featured_data/SLB.csv
# Processed and saved: featured_data/ML4T-288.csv
# Processed and saved: featured_data/ML4T-103.csv
# Processed and saved: featured_data/MAR.csv
# Processed and saved: featured_data/SYK.csv
# Processed and saved: featured_data/ML4T-074.csv
# Processed and saved: featured_data/ML4T-267.csv
# Processed and saved: featured_data/ML4T-094.csv
# Processed and saved: featured_data/JEC.csv
# Processed and saved: featured_data/MCD.csv
# Processed and saved: featured_data/NTAP.csv
# Processed and saved: featured_data/DF.csv
# Processed and saved: featured_data/MCK.csv
# Processed and saved: featured_data/PCP.csv
# Processed and saved: featured_data/ABC.csv
# Processed and saved: featured_data/MSFT.csv
# Processed and saved: featured_data/CMS.csv
# Processed and saved: featured_data/ML4T-012.csv
# Processed and saved: featured_data/APH.csv
# Processed and saved: featured_data/ML4T-020.csv
# Processed and saved: featured_data/SIAL.csv
# Processed and saved: featured_data/AGN.csv
# Processed and saved: featured_data/DUK.csv
# Processed and saved: featured_data/TIF.csv
# Processed and saved: featured_data/F.csv
# Processed and saved: featured_data/ROST.csv
# Processed and saved: featured_data/ERTS.csv
# Processed and saved: featured_data/K.csv
# Processed and saved: featured_data/CEG.csv
# Processed and saved: featured_data/ML4T-353.csv
# Processed and saved: featured_data/CSCO.csv
# Processed and saved: featured_data/CIEN.csv
# Processed and saved: featured_data/LIZ.csv
# Processed and saved: featured_data/TYC.csv
# Processed and saved: featured_data/GILD.csv
# Processed and saved: featured_data/ADSK.csv
# Processed and saved: featured_data/ML4T-289.csv
# Processed and saved: featured_data/ML4T-128.csv
# Processed and saved: featured_data/ML4T-222.csv
# Processed and saved: featured_data/LMT.csv
# Processed and saved: featured_data/BLK.csv
# Processed and saved: featured_data/ML4T-398.csv
# Processed and saved: featured_data/ML4T-244.csv
# Processed and saved: featured_data/MPC.csv
# Processed and saved: featured_data/HPCCP.csv
# Processed and saved: featured_data/IP.csv
# Processed and saved: featured_data/ML4T-351.csv
# Processed and saved: featured_data/DNB.csv
# Processed and saved: featured_data/ML4T-212.csv
# Processed and saved: featured_data/CHK.csv
# Processed and saved: featured_data/ML4T-275.csv
# Processed and saved: featured_data/ML4T-112.csv
# Processed and saved: featured_data/ML4T-217.csv
# Processed and saved: featured_data/IFF.csv
# Processed and saved: featured_data/CCT.csv
# /tmp/ipykernel_892722/2545850965.py:9: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['VROC_10'] = df['Volume'].pct_change(10)
# /tmp/ipykernel_892722/2545850965.py:10: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['VROC_20'] = df['Volume'].pct_change(20)
# Processed and saved: featured_data/ML4T-123.csv
# Processed and saved: featured_data/CCMO.csv
# Processed and saved: featured_data/ANF.csv
# Processed and saved: featured_data/PRU.csv
# Processed and saved: featured_data/SVU.csv
# Processed and saved: featured_data/WYE.csv
# Processed and saved: featured_data/AZO.csv
# Processed and saved: featured_data/GIS.csv
# Processed and saved: featured_data/ML4T-159.csv
# Processed and saved: featured_data/ML4T-010.csv
# Processed and saved: featured_data/FMC.csv
# Processed and saved: featured_data/RHT.csv
# Processed and saved: featured_data/D.csv
# Processed and saved: featured_data/CRM.csv
# Processed and saved: featured_data/FFIV.csv
# Processed and saved: featured_data/HD.csv
# Processed and saved: featured_data/ML4T-241.csv
# Processed and saved: featured_data/INTC.csv
# Processed and saved: featured_data/ML4T-170.csv
# Processed and saved: featured_data/SPG.csv
# Processed and saved: featured_data/ML4T-195.csv
# Processed and saved: featured_data/ML4T-082.csv
# Processed and saved: featured_data/ML4T-376.csv
# Processed and saved: featured_data/WY.csv
# Processed and saved: featured_data/BCR.csv
# Processed and saved: featured_data/ML4T-118.csv
# Processed and saved: featured_data/ML4T-108.csv
# Processed and saved: featured_data/GD.csv
# Processed and saved: featured_data/HP.csv
# Processed and saved: featured_data/ML4T-392.csv
# Processed and saved: featured_data/SDS.csv
# Processed and saved: featured_data/ML4T-172.csv
# Processed and saved: featured_data/ADM.csv
# Processed and saved: featured_data/SCG.csv
# Processed and saved: featured_data/ML4T-308.csv
# Processed and saved: featured_data/ML4T-115.csv
# Processed and saved: featured_data/ML4T-318.csv
# Processed and saved: featured_data/ML4T-058.csv
# Processed and saved: featured_data/HAS.csv
# Processed and saved: featured_data/APA.csv
# Processed and saved: featured_data/CBG.csv
# Processed and saved: featured_data/ML4T-306.csv
# Processed and saved: featured_data/RSG.csv
# Processed and saved: featured_data/ML4T-232.csv
# Processed and saved: featured_data/HUM.csv
# Processed and saved: featured_data/NU.csv
# Processed and saved: featured_data/ML4T-101.csv
# Processed and saved: featured_data/SNA.csv
# Processed and saved: featured_data/ML4T-382.csv
# Processed and saved: featured_data/CAT.csv
# Processed and saved: featured_data/ML4T-230.csv
# Processed and saved: featured_data/ML4T-026.csv
# Processed and saved: featured_data/MKC.csv
# Processed and saved: featured_data/BRLI.csv
# Processed and saved: featured_data/ML4T-141.csv
# Processed and saved: featured_data/ML4T-120.csv
# Processed and saved: featured_data/ML4T-039.csv
# Processed and saved: featured_data/SWY.csv
# Processed and saved: featured_data/COP.csv
# Processed and saved: featured_data/ED.csv
# Processed and saved: featured_data/ML4T-243.csv
# Processed and saved: featured_data/MTB.csv
# Processed and saved: featured_data/ML4T-337.csv
# Processed and saved: featured_data/SNI.csv
# Processed and saved: featured_data/ML4T-272.csv
# Processed and saved: featured_data/CSC.csv
# Processed and saved: featured_data/CNX.csv
# Processed and saved: featured_data/ML4T-104.csv
# Processed and saved: featured_data/APD.csv
# Processed and saved: featured_data/ML4T-266.csv
# Processed and saved: featured_data/UTX.csv
# Processed and saved: featured_data/ML4T-193.csv
# Processed and saved: featured_data/ML4T-310.csv
# Processed and saved: featured_data/ML4T-326.csv
# Processed and saved: featured_data/ML4T-374.csv
# Processed and saved: featured_data/NKE.csv
# Processed and saved: featured_data/IR.csv
# Processed and saved: featured_data/ML4T-346.csv
# Processed and saved: featured_data/EDS.csv
# Processed and saved: featured_data/ML4T-006.csv
# Processed and saved: featured_data/QCOM.csv
# Processed and saved: featured_data/ML4T-122.csv
# Processed and saved: featured_data/USB.csv
# Processed and saved: featured_data/ML4T-331.csv
# Processed and saved: featured_data/AES.csv
# Processed and saved: featured_data/ML4T-203.csv
# Processed and saved: featured_data/ML4T-341.csv
# Processed and saved: featured_data/XYL.csv
# Processed and saved: featured_data/PG.csv
# Processed and saved: featured_data/ML4T-384.csv
# Processed and saved: featured_data/WM.csv
# Processed and saved: featured_data/ML4T-075.csv
# Processed and saved: featured_data/ML4T-147.csv
# Processed and saved: featured_data/PWR.csv
# Processed and saved: featured_data/ML4T-116.csv
# Processed and saved: featured_data/ML4T-135.csv
# Processed and saved: featured_data/ML4T-059.csv
# Processed and saved: featured_data/ML4T-226.csv
# Processed and saved: featured_data/ML4T-269.csv
# Processed and saved: featured_data/ZMH.csv
# Processed and saved: featured_data/X.csv
# Processed and saved: featured_data/KEY.csv
# Processed and saved: featured_data/LO.csv
# Processed and saved: featured_data/BBT.csv
# Processed and saved: featured_data/KMB.csv
# Processed and saved: featured_data/CINF.csv
# Processed and saved: featured_data/CTXS.csv
# Processed and saved: featured_data/OXY.csv
# Processed and saved: featured_data/ML4T-086.csv
# Processed and saved: featured_data/DHR.csv
# Processed and saved: featured_data/DPS.csv
# Processed and saved: featured_data/$SPX.csv
# Processed and saved: featured_data/CTAS.csv
# Processed and saved: featured_data/MO.csv
# Processed and saved: featured_data/PAYX.csv
# Processed and saved: featured_data/ML4T-132.csv
# Processed and saved: featured_data/FITB.csv
# Processed and saved: featured_data/A.csv
# Processed and saved: featured_data/ML4T-219.csv
# Processed and saved: featured_data/ML4T-025.csv
# Processed and saved: featured_data/ML4T-365.csv
# Processed and saved: featured_data/ML4T-302.csv
# Processed and saved: featured_data/ML4T-225.csv
# Processed and saved: featured_data/COG.csv
# Processed and saved: featured_data/WPO.csv
# Processed and saved: featured_data/PTV.csv
# Processed and saved: featured_data/TSN.csv
# Processed and saved: featured_data/UNH.csv
# Processed and saved: featured_data/ML4T-262.csv
# Processed and saved: featured_data/DHI.csv
# Processed and saved: featured_data/ML4T-294.csv
# Processed and saved: featured_data/MNST.csv
# Processed and saved: featured_data/ATI.csv
# Processed and saved: featured_data/ML4T-314.csv
# Processed and saved: featured_data/BBBY.csv
# Processed and saved: featured_data/ML4T-192.csv
# Processed and saved: featured_data/ML4T-282.csv
# Processed and saved: featured_data/ML4T-038.csv
# Processed and saved: featured_data/LTD.csv
# Processed and saved: featured_data/ML4T-048.csv
# Processed and saved: featured_data/ML4T-334.csv
# Processed and saved: featured_data/ML4T-299.csv
# Processed and saved: featured_data/ML4T-036.csv
# Processed and saved: featured_data/ML4T-022.csv
# Processed and saved: featured_data/NFLX.csv
# Processed and saved: featured_data/ML4T-174.csv
# Processed and saved: featured_data/UNP.csv
# Processed and saved: featured_data/NI.csv
# Processed and saved: featured_data/EBAY.csv
# Processed and saved: featured_data/TRV.csv
# Processed and saved: featured_data/Q.csv
# Processed and saved: featured_data/ML4T-373.csv
# Processed and saved: featured_data/ML4T-114.csv
# Processed and saved: featured_data/ML4T-388.csv
# Processed and saved: featured_data/NUE.csv
# Processed and saved: featured_data/FTI.csv
# Processed and saved: featured_data/CVG.csv
# Processed and saved: featured_data/ML4T-379.csv
# Processed and saved: featured_data/LLTC.csv
# Processed and saved: featured_data/T.csv
# Processed and saved: featured_data/ML4T-292.csv
# Processed and saved: featured_data/EXPD.csv
# Processed and saved: featured_data/ML4T-134.csv
# Processed and saved: featured_data/ACE.csv
# Processed and saved: featured_data/ADI.csv
# Processed and saved: featured_data/ML4T-383.csv
# Processed and saved: featured_data/ODP.csv
# Processed and saved: featured_data/ML4T-291.csv
# Processed and saved: featured_data/ML4T-228.csv
# Processed and saved: featured_data/JCI.csv
# Processed and saved: featured_data/ML4T-003.csv
# Processed and saved: featured_data/ML4T-327.csv
# Processed and saved: featured_data/ORLY.csv
# Processed and saved: featured_data/JOY.csv
# Processed and saved: featured_data/ML4T-119.csv
# Processed and saved: featured_data/EP.csv
# Processed and saved: featured_data/FTR.csv
# Processed and saved: featured_data/WEC.csv
# Processed and saved: featured_data/ML4T-107.csv
# Processed and saved: featured_data/SE.csv
# Processed and saved: featured_data/ML4T-005.csv
# Processed and saved: featured_data/MAS.csv
# Processed and saved: featured_data/HCN.csv
# Processed and saved: featured_data/ML4T-097.csv
# Processed and saved: featured_data/KMX.csv
# Processed and saved: featured_data/CBSH.csv
# Processed and saved: featured_data/SYMC.csv
# Processed and saved: featured_data/NEM.csv
# Processed and saved: featured_data/ML4T-207.csv
# Processed and saved: featured_data/CPB.csv
# Processed and saved: featured_data/NRG.csv
# Processed and saved: featured_data/CERN.csv
# Processed and saved: featured_data/PFG.csv
# Processed and saved: featured_data/ML4T-312.csv
# Processed and saved: featured_data/SPY.csv
# Processed and saved: featured_data/ML4T-257.csv
# Processed and saved: featured_data/PCAR.csv
# Error reading data/ohlc.csv: 'Date' is not in list
# Processed and saved: featured_data/NTRS.csv
# Processed and saved: featured_data/NSM.csv
# Processed and saved: featured_data/WLP.csv
# Processed and saved: featured_data/ML4T-009.csv
# Processed and saved: featured_data/OI.csv
# Processed and saved: featured_data/DDR.csv
# Processed and saved: featured_data/M.csv
# Processed and saved: featured_data/ML4T-090.csv
# Processed and saved: featured_data/ACN.csv
# Processed and saved: featured_data/ML4T-068.csv
# Processed and saved: featured_data/C.csv
# Processed and saved: featured_data/ML4T-087.csv
# Processed and saved: featured_data/NBR.csv
# Processed and saved: featured_data/SAF.csv
# Processed and saved: featured_data/APOL.csv
# Processed and saved: featured_data/ML4T-162.csv
# Processed and saved: featured_data/ML4T-155.csv
# Processed and saved: featured_data/SUN.csv
# Processed and saved: featured_data/DDS.csv
# Processed and saved: featured_data/ML4T-198.csv
# Processed and saved: featured_data/ML4T-316.csv
# Processed and saved: featured_data/ML4T-340.csv
# Processed and saved: featured_data/CVX.csv
# Processed and saved: featured_data/TEG.csv
# Processed and saved: featured_data/ML4T-396.csv
# Processed and saved: featured_data/MA.csv
# Processed and saved: featured_data/ML4T-250.csv
# Processed and saved: featured_data/DYN.csv
# Processed and saved: featured_data/ML4T-062.csv
# Processed and saved: featured_data/URBN.csv
# Processed and saved: featured_data/ML4T-040.csv
# Processed and saved: featured_data/ECL.csv
# Processed and saved: featured_data/MU.csv
# Processed and saved: featured_data/BMC.csv
# Processed and saved: featured_data/ML4T-263.csv
# Processed and saved: featured_data/CBE.csv
# Processed and saved: featured_data/IACI.csv
# Processed and saved: featured_data/ML4T-173.csv
# Processed and saved: featured_data/ML4T-054.csv
# Processed and saved: featured_data/ML4T-081.csv
# Processed and saved: featured_data/VRSN.csv
# Processed and saved: featured_data/EL.csv
# Processed and saved: featured_data/WFR.csv
# Processed and saved: featured_data/BF.B.csv
# Processed and saved: featured_data/DRI.csv
# Processed and saved: featured_data/ML4T-279.csv
# Processed and saved: featured_data/ML4T-390.csv
# Processed and saved: featured_data/NDAQ.csv
# Processed and saved: featured_data/CNP.csv
# Processed and saved: featured_data/SNDK.csv
# Processed and saved: featured_data/MUR.csv
# Processed and saved: featured_data/ML4T-000.csv
# Processed and saved: featured_data/NOVL.csv
# Processed and saved: featured_data/ML4T-287.csv
# Processed and saved: featured_data/ML4T-278.csv
# Processed and saved: featured_data/BC.csv
# Processed and saved: featured_data/KR.csv
# Processed and saved: featured_data/VLO.csv
# Processed and saved: featured_data/STR.csv
# Processed and saved: featured_data/BLL.csv
# Processed and saved: featured_data/ML4T-133.csv
# Processed and saved: featured_data/RRC.csv
# Processed and saved: featured_data/PCS.csv
# Processed and saved: featured_data/OMC.csv
# Processed and saved: featured_data/GNW.csv
# Processed and saved: featured_data/GGP.csv
# Processed and saved: featured_data/NVDA.csv
# Processed and saved: featured_data/DO.csv
# Processed and saved: featured_data/ML4T-184.csv
# Processed and saved: featured_data/GAS.csv
# Processed and saved: featured_data/ML4T-161.csv
# Processed and saved: featured_data/BK.csv
# Processed and saved: featured_data/ML4T-254.csv
# Processed and saved: featured_data/CB.csv
# Processed and saved: featured_data/STX.csv
# Processed and saved: featured_data/FOSL.csv
# Processed and saved: featured_data/JBL.csv
# Processed and saved: featured_data/WIN.csv
# Processed and saved: featured_data/ML4T-248.csv
# Processed and saved: featured_data/DV.csv
# Processed and saved: featured_data/JWN.csv
# Processed and saved: featured_data/RF.csv
# Processed and saved: featured_data/PCLN.csv
# Processed and saved: featured_data/ML4T-253.csv
# Processed and saved: featured_data/FCX.csv
# Processed and saved: featured_data/MRO.csv
# Processed and saved: featured_data/ML4T-031.csv
# Processed and saved: featured_data/ML4T-168.csv
# Processed and saved: featured_data/ML4T-274.csv
# Processed and saved: featured_data/ML4T-342.csv
# Processed and saved: featured_data/IGT.csv
# Processed and saved: featured_data/IRM.csv
# Processed and saved: featured_data/ML4T-255.csv
# Processed and saved: featured_data/ML4T-190.csv
# Processed and saved: featured_data/DTE.csv
# Processed and saved: featured_data/ML4T-295.csv
# Processed and saved: featured_data/ML4T-206.csv
# Processed and saved: featured_data/ML4T-313.csv
# Processed and saved: featured_data/CME.csv
# Processed and saved: featured_data/PLD.csv
# Processed and saved: featured_data/ML4T-176.csv
# Processed and saved: featured_data/ALXN.csv
# Processed and saved: featured_data/WPI.csv
# Processed and saved: featured_data/ML4T-242.csv
# Processed and saved: featured_data/ML4T-280.csv
# Processed and saved: featured_data/AA.csv
# Processed and saved: featured_data/ML4T-377.csv
# Processed and saved: featured_data/AFL.csv
# Processed and saved: featured_data/GCI.csv
# Processed and saved: featured_data/RRD.csv
# Processed and saved: featured_data/ICE.csv
# Processed and saved: featured_data/ABKFQ.csv
# Processed and saved: featured_data/MOS.csv
# Processed and saved: featured_data/ML4T-399.csv
# Processed and saved: featured_data/HCP.csv
# Processed and saved: featured_data/MCO.csv
# Processed and saved: featured_data/ML4T-236.csv
# Processed and saved: featured_data/LM.csv
# Processed and saved: featured_data/ML4T-364.csv
# Processed and saved: featured_data/ML4T-177.csv
# Processed and saved: featured_data/ML4T-205.csv
# Processed and saved: featured_data/FSLR.csv
# Processed and saved: featured_data/MCHP.csv
# Processed and saved: featured_data/DGX.csv
# Processed and saved: featured_data/TAP.csv
# Processed and saved: featured_data/ESV.csv
# Processed and saved: featured_data/L.csv
# Processed and saved: featured_data/MWV.csv
# Processed and saved: featured_data/ACAS.csv
# Processed and saved: featured_data/ML4T-323.csv
# Processed and saved: featured_data/ML4T-330.csv
# Processed and saved: featured_data/HES.csv
# Processed and saved: featured_data/HAR.csv
# Processed and saved: featured_data/MHS.csv
# Processed and saved: featured_data/WFT.csv
# Processed and saved: featured_data/VFC.csv
# Processed and saved: featured_data/SBUX.csv
# Processed and saved: featured_data/NCC.csv
# Processed and saved: featured_data/COF.csv
# Processed and saved: featured_data/DOW.csv
# Processed and saved: featured_data/WYN.csv
# Processed and saved: featured_data/ML4T-064.csv
# Processed and saved: featured_data/BWA.csv
# Processed and saved: featured_data/ML4T-363.csv
# Processed and saved: featured_data/TDC.csv
# Processed and saved: featured_data/ML4T-149.csv
# Processed and saved: featured_data/ML4T-350.csv
# Processed and saved: featured_data/ML4T-052.csv
# Processed and saved: featured_data/XL.csv
# Processed and saved: featured_data/FDX.csv
# Processed and saved: featured_data/ML4T-317.csv
# Processed and saved: featured_data/NEE.csv
# Processed and saved: featured_data/SINE_FAST.csv
# Processed and saved: featured_data/ARG.csv
# Processed and saved: featured_data/ML4T-311.csv
# Processed and saved: featured_data/GE.csv
# Processed and saved: featured_data/ML4T-139.csv
# Processed and saved: featured_data/ML4T-338.csv
# Processed and saved: featured_data/ML4T-030.csv
# Processed and saved: featured_data/CSX.csv
# Processed and saved: featured_data/OMX.csv
# Processed and saved: featured_data/SRE.csv
# Processed and saved: featured_data/CMCSA.csv
# Processed and saved: featured_data/LXK.csv
# Processed and saved: featured_data/ML4T-245.csv
# Processed and saved: featured_data/CL.csv
# Processed and saved: featured_data/PPL.csv
# Processed and saved: featured_data/ML4T-017.csv
# Processed and saved: featured_data/WYNN.csv
# Processed and saved: featured_data/FII.csv
# Processed and saved: featured_data/ML4T-281.csv
# Processed and saved: featured_data/ML4T-160.csv
# Processed and saved: featured_data/CI.csv
# Processed and saved: featured_data/ML4T-252.csv
# Processed and saved: featured_data/ML4T-397.csv
# Processed and saved: featured_data/APC.csv
# Processed and saved: featured_data/LNC.csv
# Processed and saved: featured_data/MRK.csv
# Processed and saved: featured_data/ML4T-186.csv
# Processed and saved: featured_data/ML4T-391.csv
# Processed and saved: featured_data/ML4T-166.csv
# Processed and saved: featured_data/ML4T-179.csv
# Processed and saved: featured_data/CFC+A.csv
# Processed and saved: featured_data/ML4T-100.csv
# Processed and saved: featured_data/NOC.csv
# Processed and saved: featured_data/ROH.csv
# Processed and saved: featured_data/ETFC.csv
# Processed and saved: featured_data/TER.csv
# Processed and saved: featured_data/ML4T-013.csv
# Processed and saved: featured_data/NVLS.csv
# Processed and saved: featured_data/ML4T-367.csv
# Processed and saved: featured_data/BAC.csv
# Processed and saved: featured_data/DE.csv
# Processed and saved: featured_data/ML4T-283.csv
# Processed and saved: featured_data/DVA.csv
# Processed and saved: featured_data/KFT.csv
# Processed and saved: featured_data/ML4T-053.csv
# Processed and saved: featured_data/KSS.csv
# Processed and saved: featured_data/ML4T-157.csv
# Processed and saved: featured_data/ML4T-356.csv
# Processed and saved: featured_data/ML4T-046.csv
# Processed and saved: featured_data/PNC.csv
# Processed and saved: featured_data/HAL.csv
# Processed and saved: featured_data/ML4T-084.csv
# Processed and saved: featured_data/ML4T-050.csv
# Processed and saved: featured_data/TMK.csv
# Processed and saved: featured_data/ML4T-131.csv
# Processed and saved: featured_data/MON.csv
# Processed and saved: featured_data/ML4T-277.csv
# Processed and saved: featured_data/ML4T-029.csv
# Processed and saved: featured_data/ML4T-276.csv
# Processed and saved: featured_data/JAVA.csv
# Processed and saved: featured_data/FLIR.csv
# Processed and saved: featured_data/ML4T-076.csv
# Processed and saved: featured_data/ML4T-169.csv
# Processed and saved: featured_data/ISRG.csv
# Processed and saved: featured_data/ML4T-163.csv
# Processed and saved: featured_data/PKI.csv
# Processed and saved: featured_data/COH.csv
# Processed and saved: featured_data/ML4T-284.csv
# Processed and saved: featured_data/HON.csv
# Processed and saved: featured_data/ML4T-004.csv
# Processed and saved: featured_data/ML4T-069.csv
# Processed and saved: featured_data/BRCM.csv
# Processed and saved: featured_data/ML4T-260.csv
# Processed and saved: featured_data/ML4T-117.csv
# Processed and saved: featured_data/ABT.csv
# Processed and saved: featured_data/ML4T-037.csv
# Processed and saved: featured_data/ML4T-189.csv
# Processed and saved: featured_data/MWW.csv
# Processed and saved: featured_data/ML4T-113.csv
# Processed and saved: featured_data/HNZ.csv
# Processed and saved: featured_data/ADP.csv
# Processed and saved: featured_data/ML4T-227.csv
# Processed and saved: featured_data/SINE_SLOW.csv
# Processed and saved: featured_data/RSH.csv
# Processed and saved: featured_data/ML4T-270.csv
# Processed and saved: featured_data/ML4T-224.csv
# Processed and saved: featured_data/ML4T-028.csv
# Processed and saved: featured_data/ML4T-319.csv
# Processed and saved: featured_data/BIG.csv
# Processed and saved: featured_data/ML4T-210.csv
# Processed and saved: featured_data/ML4T-032.csv
# Processed and saved: featured_data/ML4T-164.csv
# Processed and saved: featured_data/SEE.csv
# Processed and saved: featured_data/ML4T-395.csv
# Processed and saved: featured_data/WMB.csv
# Processed and saved: featured_data/ML4T-329.csv
# Processed and saved: featured_data/ML4T-194.csv
# Processed and saved: featured_data/NFX.csv
# Processed and saved: featured_data/ML4T-011.csv
# Processed and saved: featured_data/ML4T-301.csv
# Processed and saved: featured_data/ML4T-213.csv
# Processed and saved: featured_data/ML4T-220.csv
# Processed and saved: featured_data/TLAB.csv
# Processed and saved: featured_data/ML4T-372.csv
# Processed and saved: featured_data/CMI.csv
# Processed and saved: featured_data/ML4T-093.csv
# Processed and saved: featured_data/PFE.csv
# Processed and saved: featured_data/SSP.csv
# Processed and saved: featured_data/GENZ.csv
# Processed and saved: featured_data/WAMUQ.csv
# Processed and saved: featured_data/DNR.csv
# Processed and saved: featured_data/ML4T-360.csv
# Processed and saved: featured_data/PGR.csv
# Processed and saved: featured_data/CCI.csv
# Processed and saved: featured_data/BMY.csv
# Processed and saved: featured_data/ML4T-171.csv
# Processed and saved: featured_data/CFN.csv
# Processed and saved: featured_data/WFC.csv
# Processed and saved: featured_data/ML4T-077.csv
# Processed and saved: featured_data/CMA.csv
# Processed and saved: featured_data/AMD.csv
# Processed and saved: featured_data/ML4T-063.csv
# Processed and saved: featured_data/ML4T-124.csv
# Processed and saved: featured_data/CBS.csv
# Processed and saved: featured_data/VAR.csv
# Processed and saved: featured_data/PBG.csv
# Processed and saved: featured_data/EMN.csv
# Processed and saved: featured_data/HCBK.csv
# Processed and saved: featured_data/XEL.csv
# Processed and saved: featured_data/STI.csv
# Processed and saved: featured_data/BTU.csv
# Processed and saved: featured_data/ML4T-165.csv
# Processed and saved: featured_data/TSO.csv
# Processed and saved: featured_data/ML4T-347.csv
# Processed and saved: featured_data/TMO.csv
# Processed and saved: featured_data/ML4T-359.csv
# Processed and saved: featured_data/ML4T-200.csv
# Processed and saved: featured_data/ML4T-070.csv
# Processed and saved: featured_data/AXP.csv
# Processed and saved: featured_data/ML4T-336.csv
# Processed and saved: featured_data/KG.csv
# Processed and saved: featured_data/ML4T-121.csv
# Processed and saved: featured_data/ML4T-387.csv
# Processed and saved: featured_data/MDT.csv
# Processed and saved: featured_data/ML4T-098.csv
# Processed and saved: featured_data/DTV.csv
# Processed and saved: featured_data/ML4T-249.csv
# Processed and saved: featured_data/TE.csv
# Processed and saved: featured_data/ML4T-148.csv
# Processed and saved: featured_data/COV.csv
# Processed and saved: featured_data/HRL.csv
# Processed and saved: featured_data/ETR.csv
# Processed and saved: featured_data/ML4T-033.csv
# Processed and saved: featured_data/ML4T-307.csv
# Processed and saved: featured_data/BBY.csv
# Processed and saved: featured_data/WEN.csv
# Processed and saved: featured_data/FE.csv
# Processed and saved: featured_data/BA.csv
# Processed and saved: featured_data/CHRW.csv
# Processed and saved: featured_data/ML4T-389.csv
# Processed and saved: featured_data/LOW.csv
# Processed and saved: featured_data/ML4T-215.csv
# Processed and saved: featured_data/ML4T-345.csv
# Processed and saved: featured_data/SO.csv
# Processed and saved: featured_data/ML4T-324.csv
# Processed and saved: featured_data/ML4T-238.csv
# Processed and saved: featured_data/AET.csv
# Processed and saved: featured_data/EMC.csv
# Processed and saved: featured_data/$VIX.csv
# Processed and saved: featured_data/CTX.csv
# Processed and saved: featured_data/LLY.csv
# Processed and saved: featured_data/ML4T-106.csv
# Processed and saved: featured_data/ML4T-111.csv
# Processed and saved: featured_data/ML4T-099.csv
# Processed and saved: featured_data/INTU.csv
# Processed and saved: featured_data/MET.csv
# Processed and saved: featured_data/ROK.csv
# Processed and saved: featured_data/TEL.csv
# Processed and saved: featured_data/MOLX.csv
# Processed and saved: featured_data/ML4T-201.csv
# Processed and saved: featured_data/JNS.csv
# Processed and saved: featured_data/RIG.csv
# Processed and saved: featured_data/DOV.csv
# Processed and saved: featured_data/ML4T-380.csv
# Processed and saved: featured_data/ITT.csv
# Processed and saved: featured_data/PBCT.csv
# Processed and saved: featured_data/ML4T-394.csv
# Processed and saved: featured_data/ASH.csv
# Processed and saved: featured_data/IPG.csv
# Processed and saved: featured_data/ML4T-354.csv
# Processed and saved: featured_data/ML4T-130.csv
# Processed and saved: featured_data/NYX.csv
# Processed and saved: featured_data/WFM.csv
# Processed and saved: featured_data/RDC.csv
# Processed and saved: featured_data/WPX.csv
# Processed and saved: featured_data/BEAM.csv
# Processed and saved: featured_data/ML4T-290.csv
# Processed and saved: featured_data/ML4T-067.csv
# Processed and saved: featured_data/R.csv
# Processed and saved: featured_data/ML4T-344.csv
# Processed and saved: featured_data/UPS.csv
# Processed and saved: featured_data/ML4T-368.csv
# Processed and saved: featured_data/BRK.B.csv
# Processed and saved: featured_data/SII.csv
# Processed and saved: featured_data/ALTR.csv
# Processed and saved: featured_data/AAPL.csv
# Processed and saved: featured_data/ML4T-110.csv
# Processed and saved: featured_data/ML4T-393.csv
# Processed and saved: featured_data/HSP.csv
# Processed and saved: featured_data/SHW.csv
# Processed and saved: featured_data/ML4T-375.csv
# Processed and saved: featured_data/ML4T-202.csv
# Processed and saved: featured_data/STZ.csv
# Processed and saved: featured_data/ML4T-386.csv
# Processed and saved: featured_data/ML4T-018.csv
# Processed and saved: featured_data/PGN.csv
# Processed and saved: featured_data/ML4T-151.csv
# Processed and saved: featured_data/AKAM.csv
# Processed and saved: featured_data/PPG.csv
# Processed and saved: featured_data/ML4T-328.csv
# Processed and saved: featured_data/ML4T-197.csv
# Processed and saved: featured_data/KO.csv
# Processed and saved: featured_data/ML4T-362.csv
# Processed and saved: featured_data/RAI.csv
# Processed and saved: featured_data/ML4T-175.csv
# Processed and saved: featured_data/VIAB.csv
# Processed and saved: featured_data/GWW.csv
# Processed and saved: featured_data/TRIP.csv
# Processed and saved: featured_data/PCG.csv
# Processed and saved: featured_data/ML4T-371.csv
# Processed and saved: featured_data/STT.csv
# Processed and saved: featured_data/ML4T-043.csv
# Processed and saved: featured_data/ML4T-369.csv
# Processed and saved: featured_data/ROP.csv
# Processed and saved: featured_data/GPC.csv
# Processed and saved: featured_data/FDO.csv
# Processed and saved: featured_data/ML4T-199.csv
# Processed and saved: featured_data/V.csv
# Processed and saved: featured_data/OKE.csv
# Processed and saved: featured_data/FNMA.csv
# Processed and saved: featured_data/YHOO.csv
# Processed and saved: featured_data/SH.csv
# Processed and saved: featured_data/WDC.csv
# Processed and saved: featured_data/ML4T-256.csv
# Processed and saved: featured_data/ML4T-187.csv
# Processed and saved: featured_data/XTO.csv
# Processed and saved: featured_data/SWK.csv
# Processed and saved: featured_data/ML4T-352.csv
# Processed and saved: featured_data/ML4T-259.csv
# Processed and saved: featured_data/EMR.csv
# Processed and saved: featured_data/DVN.csv
# Processed and saved: featured_data/AON.csv
# Processed and saved: featured_data/ML4T-271.csv
# Processed and saved: featured_data/MYL.csv
# Processed and saved: featured_data/ORCL.csv
# Processed and saved: featured_data/ML4T-296.csv
# Processed and saved: featured_data/ML4T-023.csv
# Processed and saved: featured_data/HRS.csv
# Processed and saved: featured_data/DELL.csv
# Processed and saved: featured_data/CTL.csv
# Processed and saved: featured_data/BIIB.csv
# Processed and saved: featured_data/NYT.csv
# Processed and saved: featured_data/EQR.csv
# Processed and saved: featured_data/JNY.csv
# Processed and saved: featured_data/ML4T-049.csv
# Processed and saved: featured_data/ML4T-085.csv
# Processed and saved: featured_data/ML4T-061.csv
# Processed and saved: featured_data/CF.csv
# Processed and saved: featured_data/UIS.csv
# Processed and saved: featured_data/TSS.csv
# Processed and saved: featured_data/EOG.csv
# Processed and saved: featured_data/BEN.csv
# Processed and saved: featured_data/SHLD.csv
# Processed and saved: featured_data/STJ.csv
# Processed and saved: featured_data/ML4T-019.csv
# Processed and saved: featured_data/ML4T-325.csv
# Processed and saved: featured_data/PEP.csv
# Processed and saved: featured_data/ML4T-079.csv
# Processed and saved: featured_data/XRX.csv
# Processed and saved: featured_data/GR.csv
# Processed and saved: featured_data/RTN.csv
# Processed and saved: featured_data/ML4T-182.csv
# Processed and saved: featured_data/EA.csv
# Processed and saved: featured_data/HPQ.csv
# Processed and saved: featured_data/ML4T-204.csv
# Processed and saved: featured_data/CIT.csv
# Processed and saved: featured_data/HOG.csv
# Processed and saved: featured_data/ML4T-321.csv
# Processed and saved: featured_data/$DJI.csv
# Processed and saved: featured_data/QLGC.csv
# Processed and saved: featured_data/FAST.csv
# Processed and saved: featured_data/SINE_FAST_NOISE.csv
# Processed and saved: featured_data/ML4T-303.csv
# Processed and saved: featured_data/ML4T-016.csv
# Processed and saved: featured_data/MIL.csv
# Processed and saved: featured_data/ML4T-300.csv
# Processed and saved: featured_data/PX.csv
# Processed and saved: featured_data/TWC.csv
# Processed and saved: featured_data/POM.csv
# Processed and saved: featured_data/MDP.csv
# Processed and saved: featured_data/ML4T-370.csv
# Processed and saved: featured_data/ML4T-045.csv
# Processed and saved: featured_data/LH.csv
# Processed and saved: featured_data/UST.csv
# Processed and saved: featured_data/ML4T-221.csv
# Processed and saved: featured_data/MJN.csv
# Processed and saved: featured_data/ML4T-235.csv
# Processed and saved: featured_data/MS.csv
# Processed and saved: featured_data/ML4T-378.csv
# Processed and saved: featured_data/ML4T-057.csv
# Processed and saved: featured_data/SLE.csv
# Processed and saved: featured_data/ML4T-153.csv
# Processed and saved: featured_data/ML4T-180.csv
# Processed and saved: featured_data/DLTR.csv
# Processed and saved: featured_data/PM.csv
# Processed and saved: featured_data/SAI.csv
# Processed and saved: featured_data/ML4T-285.csv
# Processed and saved: featured_data/EXC.csv
# Processed and saved: featured_data/ML4T-008.csv
# Processed and saved: featured_data/CELG.csv
# Processed and saved: featured_data/MHP.csv
# Processed and saved: featured_data/TGT.csv
# Processed and saved: featured_data/TJX.csv
# Processed and saved: featured_data/SCHW.csv
# Processed and saved: featured_data/BDX.csv
# Processed and saved: featured_data/FIS.csv
# Processed and saved: featured_data/CVC.csv
# Processed and saved: featured_data/ML4T-021.csv
# Processed and saved: featured_data/ML4T-129.csv
# Processed and saved: featured_data/ZION.csv
# Processed and saved: featured_data/ML4T-216.csv
# Processed and saved: featured_data/XLNX.csv
# Processed and saved: featured_data/IYR.csv
# Processed and saved: featured_data/ML4T-044.csv
# Processed and saved: featured_data/EQ.csv
# Processed and saved: featured_data/SPLS.csv
# /tmp/ipykernel_892722/2545850965.py:9: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['VROC_10'] = df['Volume'].pct_change(10)
# /tmp/ipykernel_892722/2545850965.py:10: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['VROC_20'] = df['Volume'].pct_change(20)
# Processed and saved: featured_data/GPS.csv
# Processed and saved: featured_data/ML4T-268.csv
# Processed and saved: featured_data/AMP.csv
# Processed and saved: featured_data/SYY.csv
# Processed and saved: featured_data/ML4T-095.csv
# Processed and saved: featured_data/ML4T-088.csv
# Processed and saved: featured_data/FMCC.csv
# Processed and saved: featured_data/WAT.csv
# Processed and saved: featured_data/UNM.csv
# Processed and saved: featured_data/SJM.csv
# Processed and saved: featured_data/ML4T-183.csv
# Processed and saved: featured_data/NWSA.csv
# Processed and saved: featured_data/TXN.csv
# Processed and saved: featured_data/PH.csv
# Processed and saved: featured_data/ML4T-322.csv
# Processed and saved: featured_data/ML4T-056.csv
# Processed and saved: featured_data/ML4T-150.csv
# Processed and saved: featured_data/HOT.csv
# Processed and saved: featured_data/PXD.csv
# Processed and saved: featured_data/LUV.csv
# Processed and saved: featured_data/ML4T-246.csv
# Processed and saved: featured_data/PDCO.csv
# Processed and saved: featured_data/AEE.csv
# Processed and saved: featured_data/ML4T-298.csv
# Processed and saved: featured_data/ALL.csv
# Processed and saved: featured_data/DIS.csv
# Processed and saved: featured_data/WMT.csv
# Processed and saved: featured_data/ML4T-007.csv
# Processed and saved: featured_data/ML4T-047.csv
# Processed and saved: featured_data/RHI.csv
# Processed and saved: featured_data/ML4T-154.csv
# Processed and saved: featured_data/AMGN.csv
# Processed and saved: featured_data/AMT.csv
# Processed and saved: featured_data/ML4T-178.csv
# Processed and saved: featured_data/PSX.csv
# Processed and saved: featured_data/AN.csv
# Processed and saved: featured_data/CAG.csv
# Processed and saved: featured_data/LEHMQ.csv
# Processed and saved: featured_data/NOV.csv
# Processed and saved: featured_data/AYE.csv
# Processed and saved: featured_data/CAH.csv
# Processed and saved: featured_data/VMC.csv
# Processed and saved: featured_data/ML4T-247.csv
# Processed and saved: featured_data/PBI.csv
# Processed and saved: featured_data/ML4T-035.csv
# Processed and saved: featured_data/ML4T-332.csv
# Processed and saved: featured_data/FLS.csv
# Processed and saved: featured_data/ML4T-146.csv
# Processed and saved: featured_data/LUK.csv
# Processed and saved: featured_data/GOOG.csv
# Processed and saved: featured_data/BDK.csv
# Processed and saved: featured_data/ML4T-361.csv
# Processed and saved: featured_data/AVP.csv
# Processed and saved: featured_data/ML4T-265.csv
# Processed and saved: featured_data/MBI.csv
# Processed and saved: featured_data/ML4T-349.csv
# Processed and saved: featured_data/ML4T-231.csv
# Processed and saved: featured_data/AEP.csv
# Processed and saved: featured_data/CPWR.csv
# Processed and saved: featured_data/VIA.B.csv
# Processed and saved: featured_data/LSI.csv
# Processed and saved: featured_data/FISV.csv
# Processed and saved: featured_data/VNO.csv
# Processed and saved: featured_data/ML4T-339.csv
# Processed and saved: featured_data/MMC.csv
# Processed and saved: featured_data/ML4T-126.csv
# Processed and saved: featured_data/NWL.csv
# Processed and saved: featured_data/JCP.csv
# Processed and saved: featured_data/KBH.csv
# Processed and saved: featured_data/ML4T-385.csv
# Processed and saved: featured_data/BHI.csv
# Processed and saved: featured_data/MI.csv
# Processed and saved: featured_data/ML4T-209.csv
# Processed and saved: featured_data/ML4T-366.csv
# Processed and saved: featured_data/AIG.csv
# Processed and saved: featured_data/KLAC.csv
# Processed and saved: featured_data/ML4T-264.csv
# Processed and saved: featured_data/DISCA.csv
# Processed and saved: featured_data/WWY.csv
# Processed and saved: featured_data/CLX.csv
# Processed and saved: featured_data/HBAN.csv
# Processed and saved: featured_data/ML4T-240.csv
# Processed and saved: featured_data/ML4T-333.csv
# Processed and saved: featured_data/ML4T-001.csv
# Processed and saved: featured_data/PSA.csv
# Processed and saved: featured_data/ML4T-015.csv
# Processed and saved: featured_data/NSC.csv
# Processed and saved: featured_data/ML4T-185.csv
# Processed and saved: featured_data/BMS.csv
# Processed and saved: featured_data/MAT.csv
# Processed and saved: featured_data/ML4T-348.csv
# Processed and saved: featured_data/CCE.csv
# Processed and saved: featured_data/ML4T-080.csv
# Processed and saved: featured_data/PCL.csv
# Processed and saved: featured_data/AIZ.csv
# Processed and saved: featured_data/ML4T-211.csv
# Processed and saved: featured_data/ML4T-297.csv
# Processed and saved: featured_data/ML4T-127.csv
# Processed and saved: featured_data/ML4T-188.csv
# Processed and saved: featured_data/SRCL.csv
# Processed and saved: featured_data/ML4T-343.csv
# Processed and saved: featured_data/ML4T-109.csv
# Processed and saved: featured_data/MTG.csv
# Processed and saved: featured_data/LRCX.csv
# Processed and saved: featured_data/WAG.csv
# Processed and saved: featured_data/ANR.csv
# Processed and saved: featured_data/AVB.csv
# Processed and saved: featured_data/ML4T-142.csv
# Processed and saved: featured_data/GM.csv
# Processed and saved: featured_data/LLL.csv
# Processed and saved: featured_data/ML4T-273.csv
# Processed and saved: featured_data/BSX.csv
# Processed and saved: featured_data/ML4T-320.csv
# Processed and saved: featured_data/ML4T-181.csv
# Processed and saved: featured_data/ML4T-355.csv
# Processed and saved: featured_data/ML4T-208.csv
# Processed and saved: featured_data/WB.csv
# Processed and saved: featured_data/WHR.csv
# Processed and saved: featured_data/ACS.csv
# Processed and saved: featured_data/NBL.csv
# Processed and saved: featured_data/ML4T-305.csv
# Processed and saved: featured_data/SWN.csv
# Processed and saved: featured_data/EQT.csv
# Processed and saved: featured_data/ML4T-055.csv
# Processed and saved: featured_data/ML4T-304.csv
# Processed and saved: featured_data/ML4T-125.csv
# Processed and saved: featured_data/ML4T-137.csv
# Processed and saved: featured_data/ML4T-196.csv
# Processed and saved: featured_data/ML4T-335.csv
# Processed and saved: featured_data/ML4T-214.csv
# Processed and saved: featured_data/ML4T-078.csv
# Processed and saved: featured_data/ML4T-223.csv
# Processed and saved: featured_data/CMG.csv
# Processed and saved: featured_data/EXPE.csv
# Processed and saved: featured_data/TROW.csv
# Processed and saved: featured_data/KIM.csv
# Processed and saved: featured_data/ML4T-315.csv
# Processed and saved: featured_data/WU.csv
# Processed and saved: featured_data/VZ.csv
# Processed and saved: featured_data/ML4T-140.csv
# Processed and saved: featured_data/ML4T-014.csv
# Processed and saved: featured_data/CTSH.csv
# Processed and saved: featured_data/ML4T-024.csv
# Processed and saved: featured_data/HSY.csv
# Processed and saved: featured_data/YUM.csv
# Processed and saved: featured_data/JNPR.csv
# Processed and saved: featured_data/ML4T-152.csv
# Processed and saved: featured_data/ML4T-002.csv
# Processed and saved: featured_data/ML4T-136.csv
# Processed and saved: featured_data/ML4T-060.csv
# Processed and saved: featured_data/ML4T-358.csv
# Processed and saved: featured_data/ML4T-083.csv
# Processed and saved: featured_data/EK.csv
# Processed and saved: featured_data/PLL.csv
# Processed and saved: featured_data/PRGO.csv
# Processed and saved: featured_data/S.csv
# Processed and saved: featured_data/DD.csv
# Processed and saved: featured_data/ML4T-073.csv
# Processed and saved: featured_data/IBM.csv
# Processed and saved: featured_data/TEX.csv
# Processed and saved: featured_data/QEP.csv
# Processed and saved: featured_data/CVS.csv
# Processed and saved: featured_data/ML4T-233.csv
# Processed and saved: featured_data/MSI.csv
# Processed and saved: featured_data/LEG.csv
# Processed and saved: featured_data/ML4T-143.csv
# Processed and saved: featured_data/GS.csv
# Processed and saved: featured_data/EW.csv
# Processed and saved: featured_data/ML4T-158.csv
# Processed and saved: featured_data/TXT.csv
# Processed and saved: featured_data/ML4T-258.csv
# Processed and saved: featured_data/ML4T-091.csv
# Processed and saved: featured_data/VTR.csv
# Processed and saved: featured_data/AMAT.csv
# Processed and saved: featured_data/CA.csv
# Processed and saved: featured_data/ML4T-251.csv
# Processed and saved: featured_data/ML4T-218.csv
# Processed and saved: featured_data/MTW.csv
# Processed and saved: featured_data/ML4T-191.csv
# Processed and saved: featured_data/FHN.csv
# Processed and saved: featured_data/COL.csv
# Processed and saved: featured_data/ML4T-096.csv
# Processed and saved: featured_data/SGP.csv
# Processed and saved: featured_data/AIV.csv
# Processed and saved: featured_data/GT.csv
# Processed and saved: featured_data/JDSU.csv
# Processed and saved: featured_data/ML4T-293.csv
# Processed and saved: featured_data/CAM.csv
# Processed and saved: featured_data/ML4T-144.csv
# Processed and saved: featured_data/ML4T-092.csv
# Processed and saved: featured_data/ML4T-237.csv
# Processed and saved: featured_data/BUD.csv
# Processed and saved: featured_data/EFX.csv
# Processed and saved: featured_data/ESRX.csv
# Processed and saved: featured_data/KMI.csv
# Processed and saved: featured_data/NE.csv
# Processed and saved: featured_data/AMZN.csv
# Processed and saved: featured_data/TIE.csv
# Processed and saved: featured_data/EIX.csv
# Processed and saved: featured_data/ML4T-167.csv
# Processed and saved: featured_data/ADBE.csv
# Processed and saved: featured_data/ML4T-229.csv
# Processed and saved: featured_data/ML4T-071.csv
# Processed and saved: featured_data/LYB.csv
# Processed and saved: featured_data/COST.csv
# Processed and saved: featured_data/ETN.csv
# Processed and saved: featured_data/FLR.csv
# Processed and saved: featured_data/HST.csv
# Processed and saved: featured_data/ML4T-034.csv
# Processed and saved: featured_data/XOM.csv
# Processed and saved: featured_data/JNJ.csv
# Processed and saved: featured_data/ML4T-138.csv
# Processed and saved: featured_data/PEG.csv
# Processed and saved: featured_data/BXP.csv
# Processed and saved: featured_data/SLM.csv
# Processed and saved: featured_data/FAKE1.csv
# Processed and saved: featured_data/CLF.csv
# Processed and saved: featured_data/GME.csv
# Processed and saved: featured_data/ML4T-089.csv
# Processed and saved: featured_data/HRB.csv
# Processed and saved: featured_data/PNW.csv
# Processed and saved: featured_data/RL.csv
# Processed and saved: featured_data/BAX.csv
# Processed and saved: featured_data/ML4T-102.csv
# Processed and saved: featured_data/ML4T-065.csv
# Processed and saved: featured_data/CCL.csv
